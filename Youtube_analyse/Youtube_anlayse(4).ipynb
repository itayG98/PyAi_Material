# %% [markdown]
# ## Imports and Installation

# %%
# ! pip install numpy
# ! pip install pandas
# ! pip install xlrd
# ! pip install matplotlib
# ! pip install seaborn
# ! pip install ipywidgets
# ! pip install plotly
# ! pip install cufflinks
# ! pip install -U scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.offline as py
import plotly.express as px
import cufflinks as cf
import math
# %matplotlib inline

# %%
py.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Load data

# %%
youtube_data = pd.read_excel('USvideos.xlsx')

# %%
youtube_data.head(5)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...

# %% [markdown]
# # Attributes

# %%
youtube_data.shape
# Out:
# (40949, 16)

# %%
youtube_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
youtube_data.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
youtube_data.nunique()
# Out:
# video_id                   6351
# trending_date               205
# title                      6455
# channel_title              2207
# category_id                  16
# publish_time               6269
# tags                       6055
# views                     40478
# likes                     29850
# dislikes                   8516
# comment_count             13773
# thumbnail_link             6352
# comments_disabled             2
# ratings_disabled              2
# video_error_or_removed        2
# description                6901
# dtype: int64

# %%
youtube_data["category_id"].nunique()
# Out:
# 16

# %%
youtube_data["category_id"].unique()
# Out:
# array([22, 24, 23, 28,  1, 25, 17, 10, 15, 27, 26,  2, 19, 20, 29, 43],
#       dtype=int64)

# %% [markdown]
# ## Multiple videos with the same ID?

# %%
youtube_data['video_id'].nunique()
# Out:
# 6351

# %%
youtube_data['video_id'].value_counts()
# Out:
# j4KvrAUjn6c    30
# 8h--kFui1JA    29
# QBL8IRJ5yHU    29
# t4pRQ0jn23Q    29
# MAjY8mCTXWk    29
#                ..
# QDHcA33yT0I     1
# 6XxA-4Jp7AU     1
# GIRJck1pVRA     1
# Wpr2WvQn-kg     1
# yz7Xq3T0YPs     1
# Name: video_id, Length: 6351, dtype: int64

# %%
youtube_data["category_id"].unique()
# Out:
# array([22, 24, 23, 28,  1, 25, 17, 10, 15, 27, 26,  2, 19, 20, 29, 43],
#       dtype=int64)

# %%
youtube_data["category_id"].value_counts()
# Out:
# 24    9964
# 10    6472
# 26    4146
# 23    3457
# 22    3210
# 25    2487
# 28    2401
# 1     2345
# 17    2174
# 27    1656
# 15     920
# 20     817
# 19     402
# 2      384
# 29      57
# 43      57
# Name: category_id, dtype: int64

# %%
youtube_data["category_id"] == 1
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40944    False
# 40945    False
# 40946    False
# 40947     True
# 40948    False
# Name: category_id, Length: 40949, dtype: bool

# %%
# youtube_data.loc[(youtube_data["category_id"] == 1)] = 'Film and Animation'

# %% [markdown]
# ## Boolean mask

# %%
youtube_data["category_id"] =='Film and Animation'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 40944    False
# 40945    False
# 40946    False
# 40947    False
# 40948    False
# Name: category_id, Length: 40949, dtype: bool

# %%
youtube_data["category_name"] = np.nan

# %%
youtube_data.loc[(youtube_data["category_id"] == 1), "category_name"] = 'Film and Animation'
youtube_data.loc[(youtube_data["category_id"] == 2), "category_name"] = 'Cars and Vehicles'
youtube_data.loc[(youtube_data["category_id"] == 10), "category_name"] = 'Music'

# %%
youtube_data.head(5)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description category_name
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...           NaN
# 1  One year after the presidential election, John...           NaN
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...           NaN
# 3  Today we find out if Link is a Nickelback amat...           NaN
# 4  I know it's been a while since we did this sho...           NaN

# %%
#youtube_data.loc[(youtube_data["category_id"] == 2)]

# %%
comments_by_cat = youtube_data.groupby(['category_id'])['comment_count'].mean().astype('int')

# %%
comments_by_cat.index = comments_by_cat.index.astype('str')

# %%
views_by_cat = youtube_data.groupby(['category_id'])['views'].mean().astype('int')

# %%
views_by_cat.index = views_by_cat.index.astype('str')

# %%
likes_by_cat = youtube_data.groupby(['category_id'])['likes'].mean().astype('int')

# %%
likes_by_cat.index = views_by_cat.index.astype('str')

# %%
fig, axis = plt.subplots(nrows=1,ncols=3 ,figsize=(14,4))
axis[0].bar(views_by_cat.index, views_by_cat, color='b',  linewidth=0.7)
axis[0].set_xlabel('Mean views by catagory')
axis[0].ticklabel_format(style='plain', axis='y' ,useLocale=True)

axis[1].bar(comments_by_cat.index, comments_by_cat ,color='r',  linewidth=0.7)
axis[1].set_xlabel('Mean comments by catagory')
axis[1].ticklabel_format(style='plain', axis='y' ,useLocale=True)

axis[2].bar(likes_by_cat.index, comments_by_cat ,color='g',  linewidth=0.7)
axis[2].set_xlabel('Mean likes by catagory')
axis[2].ticklabel_format(style='plain', axis='y' ,useLocale=True)


plt.tight_layout()

# %%
fig, ax = plt.subplots(nrows=1 , ncols=3)
fig.set_size_inches(11,5)
ax[0].pie(views_by_cat, labels=views_by_cat.index)
ax[1].pie(comments_by_cat, labels=comments_by_cat.index)
ax[2].pie(likes_by_cat, labels=comments_by_cat.index)
plt.tight_layout()

# %% [markdown]
# # Second part

# %%
youtube_data = pd.read_excel('USvideos2.xlsx')

# %%
youtube_data.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'category_name'],
#       dtype='object')

# %%
youtube_data["category_name"].value_counts().sort_values(ascending=False).head(5)
# Out:
# Entertainment       9964
# Music               6469
# How to and Style    4138
# Comedy              3457
# People and Blogs    3210
# Name: category_name, dtype: int64

# %%
youtube_data["category_name"].value_counts().sort_values(ascending=True).head(5)
# Out:
# Non Profits and Activism     57
# Cars and Vehicles           384
# Travel and Events           402
# Gaming                      805
# Pets and Animals            920
# Name: category_name, dtype: int64

# %%
youtube_data["category_name"].values
# Out:
# array(['People and Blogs', 'Entertainment', 'Comedy', ...,
#        'Entertainment', 'Film and Animation', 'Gaming'], dtype=object)

# %%
fig = plt.figure(figsize = (10,5))
sns.countplot(x = "category_name", data = youtube_data, palette = 'Set1')
fig.autofmt_xdate()

# %%
fig = plt.figure(figsize = (14,7))
sns.barplot(x = "category_name", y="views", data = youtube_data , palette = 'Set2' )
# sns.barplot(x = "category_name", y="views", data = youtube_data , palette = 'Set2' , hue="video_error_or_removed")
fig.autofmt_xdate()

# %% [markdown]
# ## plt.style setting

# %%
plt.style.use('dark_background')
fig = plt.figure(figsize = (14,7))
sns.barplot(x = "category_name", y="views", data = youtube_data , palette = 'Set2' )
# sns.barplot(x = "category_name", y="views", data = youtube_data , palette = 'Set2' , hue="video_error_or_removed")
fig.autofmt_xdate()

# %% [markdown]
# ## Pandas reminder

# %%
youtube_data.loc[youtube_data['category_name'] == 'Entertainment', 'category_id'].iloc[0]
# Out:
# 24.0

# %%
youtube_data.loc[youtube_data['category_name'] == 'Non Profits and Activism', 'category_id'].iloc[0]
# Out:
# 29.0

# %%
youtube_data.loc[youtube_data['category_id'] == 10, 'category_name'].iloc[0]
# Out:
# 'Music'

# %%
youtube_data.loc[youtube_data['category_name'] == 'Entertainment',('category_name','category_id','views')].head(3)
# Out:
#    category_name  category_id      views
# 1  Entertainment         24.0  2418783.0
# 3  Entertainment         24.0   343168.0
# 4  Entertainment         24.0  2095731.0

# %% [markdown]
# # Time

# %%
type(youtube_data.loc[1]['publish_time'])
# Out:
# str

# %%
youtube_data['publish_time'] = pd.to_datetime(youtube_data['publish_time'])

# %%
youtube_data['publish_time'] = pd.to_datetime(youtube_data['publish_time'], format = '%Y-%m-%dT%H:%M:%S.fz')

# %%
youtube_data['publish_time'].head(3)
# Out:
# 0   2017-11-13 17:13:01+00:00
# 1   2017-11-13 07:30:00+00:00
# 2   2017-11-12 19:05:24+00:00
# Name: publish_time, dtype: datetime64[ns, UTC]

# %%
type(youtube_data.loc[1]['publish_time'])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ## Change style

# %%
plt.style.use('grayscale')

# %% [markdown]
# ## Add year month day

# %%
youtube_data['year'] = youtube_data['publish_time'].dt.year
youtube_data['month'] = youtube_data['publish_time'].dt.month
youtube_data['day'] = youtube_data['publish_time'].dt.day

# %%
fig = plt.figure(figsize = (12,4))
g = sns.countplot(x = 'day', data = youtube_data)
fig.autofmt_xdate()

# %%
fig = plt.figure(figsize = (12,4))
g = sns.countplot(x = 'year', data = youtube_data)
fig.autofmt_xdate()

# %%
fig = plt.figure(figsize = (12,4))
g = sns.countplot(x = 'month', data = youtube_data)
fig.autofmt_xdate()

# %%
plt.figure(figsize = (16,7))
g = sns.lineplot(x = 'month',y = 'views', hue = 'category_name', estimator = 'mean', data = youtube_data, palette = 'muted')
