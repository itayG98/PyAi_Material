# %% [markdown]
# # <span style="color:black">Imports of libraries</span>

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import math
import random
import seaborn as sns
# !pip install xlrd

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Plotting categorial vars

# %%
names = ['Apple', 'Orange', 'Banana']
values = [10, 7, 12.5]

fig , axes = plt.subplots(nrows=1 , ncols =3 , figsize=(9,3))

axes[0].bar(names, values)
axes[1].scatter(names, values)
axes[2].plot(names, values)
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %% [markdown]
# ## Bar plot

# %%
plt.style.use('_mpl-gallery')

# make data:
x = 0.5 + np.arange(8)
y = np.random.uniform(2, 7, len(x))

# plot
fig, ax = plt.subplots( figsize=(3,2))

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# ## x y simple example

# %%
xpoints = np.array([10,50,90, 115,200])
ypoints = np.array([0,25,65, 100,200])
fig, ax = plt.subplots()
ax.plot(xpoints, ypoints)
ax.plot(xpoints, ypoints*2 , 'r+--')

# %% [markdown]
# # Marker and Colors

# %%
x = np.arange(0,300,50)
fig , axis = plt.subplots(figsize=(7,3))
axis.grid(True, linestyle='-.')
axis.tick_params(labelcolor='blue', labelsize='large', width=2)

#markers
axis.plot(x,x,marker='+')
axis.plot(x,x*2,marker='o')
axis.plot(x,x*3,marker='*')
axis.plot(x,x*4,marker='s')

#colors
axis.plot(x,x*5,color='red')
axis.plot(x,x*6,color='purple')
axis.plot(x,x*7,color='green')

#line style
axis.plot(x,x*8,ls=':')
axis.plot(x,x*9,ls='-.')
axis.plot(x,x*10,ls='--')

#mix 
axis.plot(x,x*11,ls='-.' , color='orange',marker='s')
axis.plot(x,x*12,ls='--' ,color='c' ,marker='o')

# %% [markdown]
# ## Load Excel file

# %%
python_course_xlsx = pd.read_excel("python_course.xlsx",header=1)

# %%
python_course_fig = plt.figure(figsize=(6,2))
ax = python_course_fig.add_axes([0.1,0.1,1,1])

ax.plot(python_course_xlsx['Year'],python_course_xlsx['Grade'])

ax.set_xlabel('Years')
ax.set_ylabel('Grade')
ax.set_title('Python Grades over time')
# Out:
# Text(0.5, 1.0, 'Python Grades over time')

# %% [markdown]
# ## Making subplots

# %%
sub_plot_fig ,ax = plt.subplots(nrows=1 , ncols =2 ,figsize=(7,3))
plt.tight_layout()
ax[0].plot(python_course_xlsx['Year'],python_course_xlsx['Grade'],'g*-')
ax[1].plot(python_course_xlsx['Year'],python_course_xlsx['Attendance'],'r+-')
#ax[2].plot(python_course_xlsx['Year'],python_course_xlsx['Attendance'],'c--')

# %% [markdown]
# ## Both plots on the same figure

# %%
fig = plt.figure()
fig.set_size_inches(5, 3)
ax = fig.add_axes([0.1,0.1,1.5,0.8])

ax.plot(python_course_xlsx['Year'],python_course_xlsx['Grade'], label='Grade by year' ,color='r')
ax.plot(python_course_xlsx['Year'],python_course_xlsx['Attendance'], label='Attendance by year',color='g')


#python_course_xlsx['Attendance']=python_course_xlsx['Attendance'].apply(lambda x : x*100)
#ax.plot(python_course_xlsx['Year'],python_course_xlsx['Attendance_alternative'], label='Attendance by year alter',color='g')
ax.legend(loc=6)

# %%
x = np.linspace(0,10,100)
y= x**2
wired_func = np.sin(y)*y

# %%
colors = ['b','g' , 'r' ,'c']

# %%
fig , axes = plt.subplots(nrows=1 , ncols = 4,figsize=(7,3))
plt.tight_layout()
for axis , color in zip(axes ,colors):
    axis.plot(x,y,color)

# %% [markdown]
# ##### https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html#matplotlib.axes.Axes.plot

# %% [markdown]
# ## Another plot example

# %%
fig , axes = plt.subplots(figsize=(7,2))
axes.plot(x,y ,label ='Regular' ,color='r')
axes.plot(x,y+250, label ='y+5',color='g')
axes.plot(x,y*3, label ='y3' ,color='orange')
axes.legend(loc=9)

# %%
fig = plt.figure()
fig.set_size_inches(5, 3)
axes_1 = fig.add_axes([0,0,1,1])
axes_2 = fig.add_axes([0.1,0.1,0.2,0.2])
axes_1.plot(x,wired_func ,'r--' ,lw = 0.5,label = 'Wired func')
axes_2.plot(x,y , 'g--')
axes_1.legend()

# %% [markdown]
# # Weather excersise

# %%
Weather_df = pd.read_excel("Weather.xlsx",header =1)

# %%
Weather_fig, axe = plt.subplots(figsize=(9,3))
axe.plot(Weather_df['Date'],Weather_df['Temperature'], c = 'blue',  lw = 0.5, ls = '--', marker = 'd', markerfacecolor='red' ,label = 'Temperature')
axe.legend(loc=1)

# %% [markdown]
# #### https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html

# %%
x = np.linspace(0,10,11)
y = x**2

# %%
plt.scatter(x,y)

# %% [markdown]
# ## Histogram

# %%
values = [random.randint(0,100) for _ in range(50)]

# %%
plt.hist(values)
plt.show()

# %% [markdown]
# ## Barplots

# %%
plt.boxplot([values,[v*2 for v in values],[math.sqrt(v) for v in values]] , vert=True , patch_artist = True)
plt.show()
