# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %% [markdown]
# # Read data

# %%
data = pd.read_csv('ks-projects-201801.csv')

# %% [markdown]
# # Gather succesful projs and df and failing projs

# %%
succesfull_proj = data.loc[(data['state'] == 'successful')]
failed_proj = data.loc[(data['state'] == 'failed')]

# %%
succesfull_proj
# Out:
#                 ID                                               name  \
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 11       100005484                                   Lisa Lim New CD!
# 14      1000057089  Tombstone: Old West tabletop game and miniatur...
# 18      1000070642                Mike Corey's Darkness & Light Album
# ...            ...                                                ...
# 378642   999929142  ÉPOUVANTAILS : 28mm Figurines de jeux pour KIN...
# 378644   999934908                               The Manual Bar Blade
# 378646   999943841                                The Dog Coffee Book
# 378651   999969812                                       AT THE BEACH
# 378652   999971898                        Beach Wrestling Documentary
#
#                 category main_category currency    deadline     goal  \
# ...

# %%
failed_proj
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 7       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# ...            ...                                                ...
# 378654   999975836              Homemade fresh dog food, Cleveland OH
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency   deadline     goal  \
# ...

# %% [markdown]
# # Dominant categories

# %%
failed_proj.groupby(['category','main_category']).count().sort_values('ID',ascending=False)
# Out:
#                                   ID   name  currency  deadline   goal  \
# category        main_category
# Product Design  Design         10718  10718     10718     10718  10718
# Documentary     Film & Video    8599   8599      8599      8599   8599
# Food            Food            7119   7119      7119      7119   7119
# Video Games     Games           6942   6941      6942      6942   6942
# Music           Music           6201   6201      6201      6201   6201
# ...                              ...    ...       ...       ...    ...
# Comedy          Music             10     10        10        10     10
# Literary Spaces Publishing         6      6         6         6      6
# Chiptune        Music              6      6         6         6      6
# Taxidermy       Crafts             5      5         5         5      5
# Letterpress     Publishing         4      4         4         4      4
#
#                                launched  pledged  state  backers  country  \
# ...

# %%
succesfull_proj.groupby(['category','main_category']).count().sort_values('ID',ascending=False)
# Out:
#                                  ID  name  currency  deadline  goal  launched  \
# category        main_category
# Product Design  Design         7962  7962      7962      7962  7962      7962
# Tabletop Games  Games          7866  7866      7866      7866  7866      7866
# Shorts          Film & Video   6673  6673      6673      6673  6673      6673
# Music           Music          6432  6432      6432      6432  6432      6432
# Documentary     Film & Video   5924  5924      5924      5924  5924      5924
# ...                             ...   ...       ...       ...   ...       ...
# Embroidery      Crafts           19    19        19        19    19        19
# Literary Spaces Publishing       13    13        13        13    13        13
# Comedy          Music             7     7         7         7     7         7
# Letterpress     Publishing        6     6         6         6     6         6
# Taxidermy       Crafts            5     5         5         5     5         5
#
# ...
